# %%
# %matplotlib inline
from scipy.integrate import odeint
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import itertools

# %%
# 3d Linear system
def ode(state,t):
    x = state[0]
    y = state[1]
    z = state[2]

    # Lorenz with chaotic params
    sigma = 30
    rho = 15
    beta = 7/3 
    
    dx = sigma * (y - x)
    dy = x * (rho - z) - y
    dz = x * y - beta * z
    
    # Return the state derivatives
    return [dx,dy, dz]

# %%
t = np.arange(0, 10, .01) # Times
percent = 0 #percent to truncate
trunc = int(np.floor(t.size*percent))
fig = plt.figure()
ax = Axes3D(fig)

ic = [4,5,5] #initial condition
orbit = odeint(ode, ic, t) ### Run the system  
ax.scatter(orbit[0,0],orbit[0,1],orbit[0,2], c="green",s=30)
ax.scatter(orbit[trunc:,0],orbit[trunc:,1],orbit[trunc:,2], s=5)

# %%
## Not working
# from ipywidgets import interact
# fig = plt.figure()
# ax = Axes3D(fig)

# def plot_f(x,y,z):
#     ic = [x,y,z]
#     orbit = odeint(ode, ic, t) ### Run the system  
#     ax.scatter(orbit[0,0],orbit[0,1],orbit[0,2], c="green",s=30)
#     ax.scatter(orbit[:,0],orbit[:,1],orbit[:,2], s=5)

# interact(plot_f, x=[.1,1,.1], y=[.1,1,.1], z=[.1,1,.1]) # x is initial condition

# %%
# 3d Linear system
def ode(state,t):
    x = state[0]
    y = state[1]
    z = state[2]

    # Lorenz with chaotic params
    sigma = 40
    rho = 35
    beta = 8/5 
    
    dx = sigma * (y - x)
    dy = x * (rho - z) - y
    dz = x * y - beta * z
    
    # Return the state derivatives
    return [dx,dy, dz]

# %%
t = np.arange(0, 10, .01) # Times
percent = 0 #percent to truncate
trunc = int(np.floor(t.size*percent))
fig = plt.figure()
ax = Axes3D(fig)

ic = [4,5,5] #initial condition
orbit = odeint(ode, ic, t) ### Run the system  
ax.scatter(orbit[0,0],orbit[0,1],orbit[0,2], c="green",s=30)
ax.scatter(orbit[trunc:,0],orbit[trunc:,1],orbit[trunc:,2], s=5)

# %%
# 3d Linear system
def ode(state,t):
    x = state[0]
    y = state[1]
    z = state[2]

    # Lorenz with chaotic params
    sigma = 10
    rho = 28
    beta = 8/3
    
    dx = sigma * (y - x)
    dy = x * (rho - z) - y
    dz = x * y - beta * z
    
    # Return the state derivatives
    return [dx,dy, dz]

# %%
t = np.arange(0, 30, .01) # Times
percent = 0 #percent to truncate
trunc = int(np.floor(t.size*percent))
fig = plt.figure()
ax = Axes3D(fig)

ic = [4,5,5] #initial condition
orbit = odeint(ode, ic, t) ### Run the system  
ax.scatter(orbit[0,0],orbit[0,1],orbit[0,2], c="green",s=30)
ax.scatter(orbit[trunc:,0],orbit[trunc:,1],orbit[trunc:,2], s=5)
